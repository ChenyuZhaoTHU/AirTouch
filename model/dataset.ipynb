# %%
# !pip install pandas

# %%
import pandas as pd
import os

def process_csv(file_path, output_folder):
    try:

        df = pd.read_csv(file_path)
        # df = [[float(x) for x in line.split()] for line in df]

        print(f"Processing file: {file_path}")

        # Check whether the DataFrame is empty
        if df.empty:
            print("DataFrame is empty")
            return

        # Get the last column
        last_column = df.iloc[:, -3]

        # Locate the row in the last column from top to bottom where the first value greater than 600 is located
        row_index_from_top = last_column[last_column > 600].index.min()
        # Find the row in the last column from bottom to top where the first value greater than 600 is located
        row_index_from_bottom = last_column[last_column > 600].index.max()

        # Keep the line between these two points
        if pd.notna(row_index_from_top) and pd.notna(row_index_from_bottom):
            df = df.loc[row_index_from_top:row_index_from_bottom]
        df.iloc[:, -3] = (df.iloc[:, -3] < 200).astype(int)
        # Save the processed data
        new_file_path = os.path.join(output_folder, os.path.basename(file_path))
        df.to_csv(new_file_path, index=False)

        print(f"File has been saved to: {new_file_path}")

    except Exception as e:
        print(f"Error processing file {file_path}: {e}")

input_folders = [
    'grass_fusion',
    'gras2mat_fusion',
    'mat_fusion',
    'water_fusion'
]

# Iterate through all folders
for input_folder in input_folders:
    output_folder = os.path.join(input_folder, 'allcolunm')
    
    # Create an output folder
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    # Iterate through all CSV files in the folder
    input_folder = os.path.join(input_folder, 'raw_data')
    for file in os.listdir(input_folder):
        if file.endswith('.csv'):
            process_csv(os.path.join(input_folder, file), output_folder)

# %%
import pandas as pd
import os

def process_csv(file_path, output_folder):
    try:
        # Read the CSV file
        df = pd.read_csv(file_path)

        print(f"Processing file: {file_path}")

        # Check if DataFrame is empty
        if df.empty:
            print("DataFrame is empty")
            return

        # Convert the last column: values < 200 to 1, others to 0
        # df.iloc[:, -1] = (df.iloc[:, -1] < 200).astype(int)

        # Find the index of the first and last occurrence where the last column is 1
        first_one = df[df.iloc[:, -1] == 1].index.min()
        last_one = df[df.iloc[:, -1] == 1].index.max()

        # Check if there are any 1's in the last column
        if pd.notna(first_one) and pd.notna(last_one):
            # Define the range of rows to keep
            start_row = max(0, first_one - 150)
            end_row = min(df.shape[0], last_one + 150)

            # Keep rows in the specified range
            df = df.loc[start_row:end_row, :]

        # Save the processed data to the new output folder
        new_file_path = os.path.join(output_folder, os.path.basename(file_path))
        df.to_csv(new_file_path, index=False)

        print(f"File has been saved to: {new_file_path}")

    except Exception as e:
        print(f"Error processing file {file_path}: {e}")


input_folders = [
    'grass_fusion',
    'grass2mat_fusion',
    'mat_fusion',
    'water_fusion'
]

# 遍历所有文件夹
for input_folder in input_folders:
    output_folder = os.path.join(input_folder, '150data')
    
    # Create an output folder
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    # Iterate through all CSV files in the folder
    input_folder = os.path.join(input_folder, 'raw_data')
    for file in os.listdir(input_folder):
        if file.endswith('.csv'):
            process_csv(os.path.join(input_folder, file), output_folder)
# Out:
# Processing file: grass_fusion\raw_data\imu_data_0313-0014.csv
# File has been saved to: grass_fusion\allcolunm\imu_data_0313-0014.csv
# Processing file: grass_fusion\raw_data\imu_data_0313-0016.csv
# File has been saved to: grass_fusion\allcolunm\imu_data_0313-0016.csv
# Processing file: grass_fusion\raw_data\imu_data_0313-0017.csv
# File has been saved to: grass_fusion\allcolunm\imu_data_0313-0017.csv
# Processing file: grass_fusion\raw_data\imu_data_0313-0059.csv
# File has been saved to: grass_fusion\allcolunm\imu_data_0313-0059.csv
# Processing file: grass_fusion\raw_data\imu_data_0313-0100.csv
# File has been saved to: grass_fusion\allcolunm\imu_data_0313-0100.csv
# Processing file: grass_fusion\raw_data\imu_data_0313-0102.csv
# File has been saved to: grass_fusion\allcolunm\imu_data_0313-0102.csv
# Processing file: grass_fusion\raw_data\imu_data_0313-0103.csv
# File has been saved to: grass_fusion\allcolunm\imu_data_0313-0103.csv
# Processing file: grass_fusion\raw_data\imu_data_0313-0104.csv
# File has been saved to: grass_fusion\allcolunm\imu_data_0313-0104.csv
# Processing file: grass_fusion\raw_data\imu_data_0313-0105.csv
# File has been saved to: grass_fusion\allcolunm\imu_data_0313-0105.csv
# Processing file: grass_fusion\raw_data\imu_data_0313-0106.csv
# File has been saved to: grass_fusion\allcolunm\imu_data_0313-0106.csv
# Processing file: grass_fusion\raw_data\imu_data_0313-0107.csv
# File has been saved to: grass_fusion\allcolunm\imu_data_0313-0107.csv
# Processing file: grass_fusion\raw_data\imu_data_0313-0108.csv
# File has been saved to: grass_fusion\allcolunm\imu_data_0313-0108.csv
# Processing file: grass_fusion\raw_data\imu_data_0313-0109.csv
# File has been saved to: grass_fusion\allcolunm\imu_data_0313-0109.csv
# Processing file: grass_fusion\raw_data\imu_data_0313-0110.csv
# File has been saved to: grass_fusion\allcolunm\imu_data_0313-0110.csv
# Processing file: grass_fusion\raw_data\imu_data_0313-0111.csv
# File has been saved to: grass_fusion\allcolunm\imu_data_0313-0111.csv
# Processing file: grass_fusion\raw_data\imu_data_0313-0112.csv
# File has been saved to: grass_fusion\allcolunm\imu_data_0313-0112.csv
# Processing file: grass_fusion\raw_data\imu_data_0313-0113.csv
# File has been saved to: grass_fusion\allcolunm\imu_data_0313-0113.csv
# Processing file: grass_fusion\raw_data\imu_data_0313-0114.csv
# File has been saved to: grass_fusion\allcolunm\imu_data_0313-0114.csv
# Processing file: grass_fusion\raw_data\imu_data_0313-0115.csv
# File has been saved to: grass_fusion\allcolunm\imu_data_0313-0115.csv
# Processing file: grass_fusion\raw_data\imu_data_0313-0116.csv
# File has been saved to: grass_fusion\allcolunm\imu_data_0313-0116.csv
# Processing file: grass_fusion\raw_data\imu_data_0313-0121.csv
# File has been saved to: grass_fusion\allcolunm\imu_data_0313-0121.csv
# Processing file: grass_fusion\raw_data\imu_data_0313-0122.csv
# File has been saved to: grass_fusion\allcolunm\imu_data_0313-0122.csv
# Processing file: grass_fusion\raw_data\imu_data_0313-0123.csv
# File has been saved to: grass_fusion\allcolunm\imu_data_0313-0123.csv
# Processing file: grass_fusion\raw_data\imu_data_0313-0129.csv
# File has been saved to: grass_fusion\allcolunm\imu_data_0313-0129.csv
# Processing file: grass_fusion\raw_data\imu_data_0313-0130.csv
# File has been saved to: grass_fusion\allcolunm\imu_data_0313-0130.csv
# Processing file: grass_fusion\raw_data\imu_data_0313-0131.csv
# File has been saved to: grass_fusion\allcolunm\imu_data_0313-0131.csv
# Processing file: grass_fusion\raw_data\imu_data_0313-0132.csv
# File has been saved to: grass_fusion\allcolunm\imu_data_0313-0132.csv
# Processing file: grass_fusion\raw_data\imu_data_0313-0133.csv
# File has been saved to: grass_fusion\allcolunm\imu_data_0313-0133.csv
# Processing file: grass_fusion\raw_data\imu_data_0313-0134.csv
# File has been saved to: grass_fusion\allcolunm\imu_data_0313-0134.csv
# Processing file: grass_fusion\raw_data\imu_data_0313-0135.csv
# File has been saved to: grass_fusion\allcolunm\imu_data_0313-0135.csv
# Processing file: grass_fusion\raw_data\imu_data_0313-0136.csv
# File has been saved to: grass_fusion\allcolunm\imu_data_0313-0136.csv
# Processing file: grass_fusion\raw_data\imu_data_0313-0137.csv
# File has been saved to: grass_fusion\allcolunm\imu_data_0313-0137.csv
# Processing file: grass_fusion\raw_data\imu_data_0313-0138.csv
# File has been saved to: grass_fusion\allcolunm\imu_data_0313-0138.csv
# Processing file: grass_fusion\raw_data\imu_data_0313-0139.csv
# File has been saved to: grass_fusion\allcolunm\imu_data_0313-0139.csv
# Processing file: grass_fusion\raw_data\imu_data_0313-0140.csv
# File has been saved to: grass_fusion\allcolunm\imu_data_0313-0140.csv
# Processing file: grass_fusion\raw_data\imu_data_0313-0143.csv
# File has been saved to: grass_fusion\allcolunm\imu_data_0313-0143.csv
# Processing file: grass_fusion\raw_data\imu_data_0313-0144.csv
# File has been saved to: grass_fusion\allcolunm\imu_data_0313-0144.csv
# Processing file: grass_fusion\raw_data\imu_data_0313-0145.csv
# File has been saved to: grass_fusion\allcolunm\imu_data_0313-0145.csv
# Processing file: grass_fusion\raw_data\imu_data_0313-0146.csv
# File has been saved to: grass_fusion\allcolunm\imu_data_0313-0146.csv
# Processing file: grass_fusion\raw_data\imu_data_0313-0147.csv
# File has been saved to: grass_fusion\allcolunm\imu_data_0313-0147.csv
# Processing file: grass_fusion\raw_data\imu_data_0313-0148.csv
# File has been saved to: grass_fusion\allcolunm\imu_data_0313-0148.csv
# Processing file: grass_fusion\raw_data\imu_data_0313-0149.csv
# File has been saved to: grass_fusion\allcolunm\imu_data_0313-0149.csv
# Processing file: grass_fusion\raw_data\imu_data_0313-0150.csv
# File has been saved to: grass_fusion\allcolunm\imu_data_0313-0150.csv
# Processing file: grass_fusion\raw_data\imu_data_0313-0151.csv
# File has been saved to: grass_fusion\allcolunm\imu_data_0313-0151.csv
# Processing file: grass_fusion\raw_data\imu_data_0313-0152.csv
# File has been saved to: grass_fusion\allcolunm\imu_data_0313-0152.csv
# Processing file: grass_fusion\raw_data\imu_data_0313-0153.csv
# File has been saved to: grass_fusion\allcolunm\imu_data_0313-0153.csv
# Processing file: grass_fusion\raw_data\imu_data_0313-0154.csv
# File has been saved to: grass_fusion\allcolunm\imu_data_0313-0154.csv
# Processing file: grass_fusion\raw_data\imu_data_0313-0156.csv
# File has been saved to: grass_fusion\allcolunm\imu_data_0313-0156.csv
# Processing file: grass_fusion\raw_data\imu_data_0313-0157.csv
# File has been saved to: grass_fusion\allcolunm\imu_data_0313-0157.csv
# Processing file: grass_fusion\raw_data\imu_data_0313-0158.csv
# File has been saved to: grass_fusion\allcolunm\imu_data_0313-0158.csv
# Processing file: grass2mat_fusion\raw_data\imu_data_0313-1628.csv
# File has been saved to: grass2mat_fusion\allcolunm\imu_data_0313-1628.csv
# Processing file: grass2mat_fusion\raw_data\imu_data_0313-1630.csv
# File has been saved to: grass2mat_fusion\allcolunm\imu_data_0313-1630.csv
# Processing file: grass2mat_fusion\raw_data\imu_data_0313-1635.csv
# File has been saved to: grass2mat_fusion\allcolunm\imu_data_0313-1635.csv
# Processing file: grass2mat_fusion\raw_data\imu_data_0313-1639.csv
# File has been saved to: grass2mat_fusion\allcolunm\imu_data_0313-1639.csv
# Processing file: grass2mat_fusion\raw_data\imu_data_0313-1640.csv
# File has been saved to: grass2mat_fusion\allcolunm\imu_data_0313-1640.csv
# Processing file: grass2mat_fusion\raw_data\imu_data_0313-1647.csv
# File has been saved to: grass2mat_fusion\allcolunm\imu_data_0313-1647.csv
# Processing file: grass2mat_fusion\raw_data\imu_data_0313-1657.csv
# File has been saved to: grass2mat_fusion\allcolunm\imu_data_0313-1657.csv
# Processing file: grass2mat_fusion\raw_data\imu_data_0313-1659.csv
# File has been saved to: grass2mat_fusion\allcolunm\imu_data_0313-1659.csv
# Processing file: grass2mat_fusion\raw_data\imu_data_0313-1701.csv
# File has been saved to: grass2mat_fusion\allcolunm\imu_data_0313-1701.csv
# Processing file: grass2mat_fusion\raw_data\imu_data_0313-1702.csv
# File has been saved to: grass2mat_fusion\allcolunm\imu_data_0313-1702.csv
# Processing file: grass2mat_fusion\raw_data\imu_data_0313-1725.csv
# File has been saved to: grass2mat_fusion\allcolunm\imu_data_0313-1725.csv
# Processing file: grass2mat_fusion\raw_data\imu_data_0313-1726.csv
# File has been saved to: grass2mat_fusion\allcolunm\imu_data_0313-1726.csv
# Processing file: grass2mat_fusion\raw_data\imu_data_0313-1728.csv
# File has been saved to: grass2mat_fusion\allcolunm\imu_data_0313-1728.csv
# Processing file: grass2mat_fusion\raw_data\imu_data_0313-1729.csv
# File has been saved to: grass2mat_fusion\allcolunm\imu_data_0313-1729.csv
# Processing file: grass2mat_fusion\raw_data\imu_data_0313-1731.csv
# File has been saved to: grass2mat_fusion\allcolunm\imu_data_0313-1731.csv
# Processing file: grass2mat_fusion\raw_data\imu_data_0313-1732.csv
# File has been saved to: grass2mat_fusion\allcolunm\imu_data_0313-1732.csv
# Processing file: grass2mat_fusion\raw_data\imu_data_0313-1733.csv
# File has been saved to: grass2mat_fusion\allcolunm\imu_data_0313-1733.csv
# Processing file: grass2mat_fusion\raw_data\imu_data_0313-1734.csv
# File has been saved to: grass2mat_fusion\allcolunm\imu_data_0313-1734.csv
# Processing file: grass2mat_fusion\raw_data\imu_data_0313-1737.csv
# File has been saved to: grass2mat_fusion\allcolunm\imu_data_0313-1737.csv
# Processing file: grass2mat_fusion\raw_data\imu_data_0313-1738.csv
# File has been saved to: grass2mat_fusion\allcolunm\imu_data_0313-1738.csv
# Processing file: grass2mat_fusion\raw_data\imu_data_0313-1739.csv
# File has been saved to: grass2mat_fusion\allcolunm\imu_data_0313-1739.csv
# Processing file: grass2mat_fusion\raw_data\imu_data_0313-1740.csv
# File has been saved to: grass2mat_fusion\allcolunm\imu_data_0313-1740.csv
# Processing file: grass2mat_fusion\raw_data\imu_data_0313-1747.csv
# File has been saved to: grass2mat_fusion\allcolunm\imu_data_0313-1747.csv
# Processing file: grass2mat_fusion\raw_data\imu_data_0313-1749.csv
# File has been saved to: grass2mat_fusion\allcolunm\imu_data_0313-1749.csv
# Processing file: grass2mat_fusion\raw_data\imu_data_0313-1750.csv
# File has been saved to: grass2mat_fusion\allcolunm\imu_data_0313-1750.csv
# Processing file: grass2mat_fusion\raw_data\imu_data_0313-1754.csv
# File has been saved to: grass2mat_fusion\allcolunm\imu_data_0313-1754.csv
# Processing file: grass2mat_fusion\raw_data\imu_data_0313-1755.csv
# File has been saved to: grass2mat_fusion\allcolunm\imu_data_0313-1755.csv
# Processing file: grass2mat_fusion\raw_data\imu_data_0313-1756.csv
# File has been saved to: grass2mat_fusion\allcolunm\imu_data_0313-1756.csv
# Processing file: grass2mat_fusion\raw_data\imu_data_0313-1757.csv
# File has been saved to: grass2mat_fusion\allcolunm\imu_data_0313-1757.csv
# Processing file: grass2mat_fusion\raw_data\imu_data_0313-1758.csv
# File has been saved to: grass2mat_fusion\allcolunm\imu_data_0313-1758.csv
# Processing file: grass2mat_fusion\raw_data\imu_data_0313-1759.csv
# File has been saved to: grass2mat_fusion\allcolunm\imu_data_0313-1759.csv
# Processing file: grass2mat_fusion\raw_data\imu_data_0313-1800.csv
# File has been saved to: grass2mat_fusion\allcolunm\imu_data_0313-1800.csv
# Processing file: grass2mat_fusion\raw_data\imu_data_0313-1801.csv
# File has been saved to: grass2mat_fusion\allcolunm\imu_data_0313-1801.csv
# Processing file: grass2mat_fusion\raw_data\imu_data_0313-1802.csv
# File has been saved to: grass2mat_fusion\allcolunm\imu_data_0313-1802.csv
# Processing file: grass2mat_fusion\raw_data\imu_data_0313-1803.csv
# File has been saved to: grass2mat_fusion\allcolunm\imu_data_0313-1803.csv
# Processing file: grass2mat_fusion\raw_data\imu_data_0313-1808.csv
# File has been saved to: grass2mat_fusion\allcolunm\imu_data_0313-1808.csv
# Processing file: grass2mat_fusion\raw_data\imu_data_0313-1814.csv
# File has been saved to: grass2mat_fusion\allcolunm\imu_data_0313-1814.csv
# Processing file: grass2mat_fusion\raw_data\imu_data_0313-1815.csv
# File has been saved to: grass2mat_fusion\allcolunm\imu_data_0313-1815.csv
# Processing file: grass2mat_fusion\raw_data\imu_data_0313-1816.csv
# File has been saved to: grass2mat_fusion\allcolunm\imu_data_0313-1816.csv
# Processing file: grass2mat_fusion\raw_data\imu_data_0313-1822.csv
# File has been saved to: grass2mat_fusion\allcolunm\imu_data_0313-1822.csv
# Processing file: grass2mat_fusion\raw_data\imu_data_0313-1823.csv
# File has been saved to: grass2mat_fusion\allcolunm\imu_data_0313-1823.csv
# Processing file: grass2mat_fusion\raw_data\imu_data_0313-1824.csv
# File has been saved to: grass2mat_fusion\allcolunm\imu_data_0313-1824.csv
# Processing file: grass2mat_fusion\raw_data\imu_data_0313-1825.csv
# File has been saved to: grass2mat_fusion\allcolunm\imu_data_0313-1825.csv
# Processing file: grass2mat_fusion\raw_data\imu_data_0313-1826.csv
# File has been saved to: grass2mat_fusion\allcolunm\imu_data_0313-1826.csv
# Processing file: grass2mat_fusion\raw_data\imu_data_0313-1827.csv
# File has been saved to: grass2mat_fusion\allcolunm\imu_data_0313-1827.csv
# Processing file: grass2mat_fusion\raw_data\imu_data_0313-1828.csv
# File has been saved to: grass2mat_fusion\allcolunm\imu_data_0313-1828.csv
# Processing file: grass2mat_fusion\raw_data\imu_data_0313-1829.csv
# File has been saved to: grass2mat_fusion\allcolunm\imu_data_0313-1829.csv
# Processing file: grass2mat_fusion\raw_data\imu_data_0313-1830.csv
# File has been saved to: grass2mat_fusion\allcolunm\imu_data_0313-1830.csv
# Processing file: grass2mat_fusion\raw_data\imu_data_0313-1831.csv
# File has been saved to: grass2mat_fusion\allcolunm\imu_data_0313-1831.csv
# Processing file: grass2mat_fusion\raw_data\imu_data_0313-1832.csv
# File has been saved to: grass2mat_fusion\allcolunm\imu_data_0313-1832.csv
# Processing file: mat_fusion\raw_data\imu_data_0310-1641.csv
# File has been saved to: mat_fusion\allcolunm\imu_data_0310-1641.csv
# Processing file: mat_fusion\raw_data\imu_data_0310-1642.csv
# File has been saved to: mat_fusion\allcolunm\imu_data_0310-1642.csv
# Processing file: mat_fusion\raw_data\imu_data_0310-1643.csv
# File has been saved to: mat_fusion\allcolunm\imu_data_0310-1643.csv
# Processing file: mat_fusion\raw_data\imu_data_0310-1644.csv
# File has been saved to: mat_fusion\allcolunm\imu_data_0310-1644.csv
# Processing file: mat_fusion\raw_data\imu_data_0310-1645.csv
# File has been saved to: mat_fusion\allcolunm\imu_data_0310-1645.csv
# Processing file: mat_fusion\raw_data\imu_data_0310-1646.csv
# File has been saved to: mat_fusion\allcolunm\imu_data_0310-1646.csv
# Processing file: mat_fusion\raw_data\imu_data_0310-1647.csv
# File has been saved to: mat_fusion\allcolunm\imu_data_0310-1647.csv
# Processing file: mat_fusion\raw_data\imu_data_0310-1648.csv
# File has been saved to: mat_fusion\allcolunm\imu_data_0310-1648.csv
# Processing file: mat_fusion\raw_data\imu_data_0310-1649.csv
# File has been saved to: mat_fusion\allcolunm\imu_data_0310-1649.csv
# Processing file: mat_fusion\raw_data\imu_data_0310-1650.csv
# File has been saved to: mat_fusion\allcolunm\imu_data_0310-1650.csv
# Processing file: mat_fusion\raw_data\imu_data_0310-1652.csv
# File has been saved to: mat_fusion\allcolunm\imu_data_0310-1652.csv
# Processing file: mat_fusion\raw_data\imu_data_0310-1653.csv
# File has been saved to: mat_fusion\allcolunm\imu_data_0310-1653.csv
# Processing file: mat_fusion\raw_data\imu_data_0310-1654.csv
# File has been saved to: mat_fusion\allcolunm\imu_data_0310-1654.csv
# Processing file: mat_fusion\raw_data\imu_data_0310-1655.csv
# File has been saved to: mat_fusion\allcolunm\imu_data_0310-1655.csv
# Processing file: mat_fusion\raw_data\imu_data_0310-1656.csv
# File has been saved to: mat_fusion\allcolunm\imu_data_0310-1656.csv
# Processing file: mat_fusion\raw_data\imu_data_0310-1657.csv
# File has been saved to: mat_fusion\allcolunm\imu_data_0310-1657.csv
# Processing file: mat_fusion\raw_data\imu_data_0310-1658.csv
# File has been saved to: mat_fusion\allcolunm\imu_data_0310-1658.csv
# Processing file: mat_fusion\raw_data\imu_data_0310-1659.csv
# File has been saved to: mat_fusion\allcolunm\imu_data_0310-1659.csv
# Processing file: mat_fusion\raw_data\imu_data_0310-1700.csv
# File has been saved to: mat_fusion\allcolunm\imu_data_0310-1700.csv
# Processing file: mat_fusion\raw_data\imu_data_0310-1702.csv
# File has been saved to: mat_fusion\allcolunm\imu_data_0310-1702.csv
# Processing file: mat_fusion\raw_data\imu_data_0310-1703.csv
# File has been saved to: mat_fusion\allcolunm\imu_data_0310-1703.csv
# Processing file: mat_fusion\raw_data\imu_data_0310-1704.csv
# File has been saved to: mat_fusion\allcolunm\imu_data_0310-1704.csv
# Processing file: mat_fusion\raw_data\imu_data_0310-1705.csv
# File has been saved to: mat_fusion\allcolunm\imu_data_0310-1705.csv
# Processing file: mat_fusion\raw_data\imu_data_0310-1706.csv
# File has been saved to: mat_fusion\allcolunm\imu_data_0310-1706.csv
# Processing file: mat_fusion\raw_data\imu_data_0310-1708.csv
# File has been saved to: mat_fusion\allcolunm\imu_data_0310-1708.csv
# Processing file: mat_fusion\raw_data\imu_data_0310-1709.csv
# File has been saved to: mat_fusion\allcolunm\imu_data_0310-1709.csv
# Processing file: mat_fusion\raw_data\imu_data_0310-1710.csv
# File has been saved to: mat_fusion\allcolunm\imu_data_0310-1710.csv
# Processing file: mat_fusion\raw_data\imu_data_0310-1711.csv
# File has been saved to: mat_fusion\allcolunm\imu_data_0310-1711.csv
# Processing file: mat_fusion\raw_data\imu_data_0310-1712.csv
# File has been saved to: mat_fusion\allcolunm\imu_data_0310-1712.csv
# Processing file: mat_fusion\raw_data\imu_data_0310-1713.csv
# File has been saved to: mat_fusion\allcolunm\imu_data_0310-1713.csv
# Processing file: mat_fusion\raw_data\imu_data_0310-1730.csv
# File has been saved to: mat_fusion\allcolunm\imu_data_0310-1730.csv
# Processing file: mat_fusion\raw_data\imu_data_0310-1731.csv
# File has been saved to: mat_fusion\allcolunm\imu_data_0310-1731.csv
# Processing file: mat_fusion\raw_data\imu_data_0310-1732.csv
# File has been saved to: mat_fusion\allcolunm\imu_data_0310-1732.csv
# Processing file: mat_fusion\raw_data\imu_data_0310-1733.csv
# File has been saved to: mat_fusion\allcolunm\imu_data_0310-1733.csv
# Processing file: mat_fusion\raw_data\imu_data_0310-1734.csv
# File has been saved to: mat_fusion\allcolunm\imu_data_0310-1734.csv
# Processing file: mat_fusion\raw_data\imu_data_0312-2323.csv
# File has been saved to: mat_fusion\allcolunm\imu_data_0312-2323.csv
# Processing file: mat_fusion\raw_data\imu_data_0312-2324.csv
# File has been saved to: mat_fusion\allcolunm\imu_data_0312-2324.csv
# Processing file: mat_fusion\raw_data\imu_data_0312-2329.csv
# File has been saved to: mat_fusion\allcolunm\imu_data_0312-2329.csv
# Processing file: mat_fusion\raw_data\imu_data_0312-2330.csv
# File has been saved to: mat_fusion\allcolunm\imu_data_0312-2330.csv
# Processing file: mat_fusion\raw_data\imu_data_0312-2331.csv
# File has been saved to: mat_fusion\allcolunm\imu_data_0312-2331.csv
# Processing file: mat_fusion\raw_data\imu_data_0312-2332.csv
# File has been saved to: mat_fusion\allcolunm\imu_data_0312-2332.csv
# Processing file: mat_fusion\raw_data\imu_data_0312-2334.csv
# File has been saved to: mat_fusion\allcolunm\imu_data_0312-2334.csv
# Processing file: mat_fusion\raw_data\imu_data_0312-2338.csv
# File has been saved to: mat_fusion\allcolunm\imu_data_0312-2338.csv
# Processing file: mat_fusion\raw_data\imu_data_0312-2339.csv
# File has been saved to: mat_fusion\allcolunm\imu_data_0312-2339.csv
# Processing file: mat_fusion\raw_data\imu_data_0312-2340.csv
# File has been saved to: mat_fusion\allcolunm\imu_data_0312-2340.csv
# Processing file: mat_fusion\raw_data\imu_data_0312-2341.csv
# File has been saved to: mat_fusion\allcolunm\imu_data_0312-2341.csv
# Processing file: mat_fusion\raw_data\imu_data_0312-2344.csv
# File has been saved to: mat_fusion\allcolunm\imu_data_0312-2344.csv
# Processing file: mat_fusion\raw_data\imu_data_0312-2352.csv
# File has been saved to: mat_fusion\allcolunm\imu_data_0312-2352.csv
# Processing file: mat_fusion\raw_data\imu_data_0312-2353.csv
# File has been saved to: mat_fusion\allcolunm\imu_data_0312-2353.csv
# Processing file: mat_fusion\raw_data\imu_data_0312-2354.csv
# File has been saved to: mat_fusion\allcolunm\imu_data_0312-2354.csv
# Processing file: water_fusion\raw_data\imu_data_0314-0212.csv
# File has been saved to: water_fusion\allcolunm\imu_data_0314-0212.csv
# Processing file: water_fusion\raw_data\imu_data_0314-0215.csv
# File has been saved to: water_fusion\allcolunm\imu_data_0314-0215.csv
# Processing file: water_fusion\raw_data\imu_data_0314-0219.csv
# File has been saved to: water_fusion\allcolunm\imu_data_0314-0219.csv
# Processing file: water_fusion\raw_data\imu_data_0314-0220.csv
# File has been saved to: water_fusion\allcolunm\imu_data_0314-0220.csv
# Processing file: water_fusion\raw_data\imu_data_0314-0235.csv
# File has been saved to: water_fusion\allcolunm\imu_data_0314-0235.csv
# Processing file: water_fusion\raw_data\imu_data_0314-0236.csv
# File has been saved to: water_fusion\allcolunm\imu_data_0314-0236.csv
# Processing file: water_fusion\raw_data\imu_data_0314-0237.csv
# File has been saved to: water_fusion\allcolunm\imu_data_0314-0237.csv
# Processing file: water_fusion\raw_data\imu_data_0314-023953.csv
# File has been saved to: water_fusion\allcolunm\imu_data_0314-023953.csv
# Processing file: water_fusion\raw_data\imu_data_0314-024208.csv
# File has been saved to: water_fusion\allcolunm\imu_data_0314-024208.csv
# Processing file: water_fusion\raw_data\imu_data_0314-024243.csv
# File has been saved to: water_fusion\allcolunm\imu_data_0314-024243.csv
# Processing file: water_fusion\raw_data\imu_data_0314-024315.csv
# File has been saved to: water_fusion\allcolunm\imu_data_0314-024315.csv
# Processing file: water_fusion\raw_data\imu_data_0314-024347.csv
# File has been saved to: water_fusion\allcolunm\imu_data_0314-024347.csv
# Processing file: water_fusion\raw_data\imu_data_0314-025019.csv
# File has been saved to: water_fusion\allcolunm\imu_data_0314-025019.csv
# Processing file: water_fusion\raw_data\imu_data_0314-025052.csv
# File has been saved to: water_fusion\allcolunm\imu_data_0314-025052.csv
# Processing file: water_fusion\raw_data\imu_data_0314-025256.csv
# File has been saved to: water_fusion\allcolunm\imu_data_0314-025256.csv
# Processing file: water_fusion\raw_data\imu_data_0314-025338.csv
# File has been saved to: water_fusion\allcolunm\imu_data_0314-025338.csv
# Processing file: water_fusion\raw_data\imu_data_0314-025429.csv
# File has been saved to: water_fusion\allcolunm\imu_data_0314-025429.csv
# Processing file: water_fusion\raw_data\imu_data_0314-025515.csv
# File has been saved to: water_fusion\allcolunm\imu_data_0314-025515.csv
# Processing file: water_fusion\raw_data\imu_data_0314-025614.csv
# File has been saved to: water_fusion\allcolunm\imu_data_0314-025614.csv
# Processing file: water_fusion\raw_data\imu_data_0314-025646.csv
# File has been saved to: water_fusion\allcolunm\imu_data_0314-025646.csv
# Processing file: water_fusion\raw_data\imu_data_0314-025718.csv
# File has been saved to: water_fusion\allcolunm\imu_data_0314-025718.csv
# Processing file: water_fusion\raw_data\imu_data_0314-025755.csv
# File has been saved to: water_fusion\allcolunm\imu_data_0314-025755.csv
# Processing file: water_fusion\raw_data\imu_data_0314-025831.csv
# File has been saved to: water_fusion\allcolunm\imu_data_0314-025831.csv
# Processing file: water_fusion\raw_data\imu_data_0314-030354.csv
# File has been saved to: water_fusion\allcolunm\imu_data_0314-030354.csv
# Processing file: water_fusion\raw_data\imu_data_0314-030430.csv
# File has been saved to: water_fusion\allcolunm\imu_data_0314-030430.csv
# Processing file: water_fusion\raw_data\imu_data_0314-030519.csv
# File has been saved to: water_fusion\allcolunm\imu_data_0314-030519.csv
# Processing file: water_fusion\raw_data\imu_data_0314-030602.csv
# File has been saved to: water_fusion\allcolunm\imu_data_0314-030602.csv
# Processing file: water_fusion\raw_data\imu_data_0314-030654.csv
# File has been saved to: water_fusion\allcolunm\imu_data_0314-030654.csv
# Processing file: water_fusion\raw_data\imu_data_0314-030738.csv
# File has been saved to: water_fusion\allcolunm\imu_data_0314-030738.csv
# Processing file: water_fusion\raw_data\imu_data_0314-030821.csv
# File has been saved to: water_fusion\allcolunm\imu_data_0314-030821.csv
# Processing file: water_fusion\raw_data\imu_data_0314-030910.csv
# File has been saved to: water_fusion\allcolunm\imu_data_0314-030910.csv
# Processing file: water_fusion\raw_data\imu_data_0314-031011.csv
# File has been saved to: water_fusion\allcolunm\imu_data_0314-031011.csv
# Processing file: water_fusion\raw_data\imu_data_0314-031056.csv
# File has been saved to: water_fusion\allcolunm\imu_data_0314-031056.csv
# Processing file: water_fusion\raw_data\imu_data_0314-031156.csv
# File has been saved to: water_fusion\allcolunm\imu_data_0314-031156.csv
# Processing file: water_fusion\raw_data\imu_data_0314-031240.csv
# File has been saved to: water_fusion\allcolunm\imu_data_0314-031240.csv
# Processing file: water_fusion\raw_data\imu_data_0314-031322.csv
# File has been saved to: water_fusion\allcolunm\imu_data_0314-031322.csv
# Processing file: water_fusion\raw_data\imu_data_0314-031355.csv
# File has been saved to: water_fusion\allcolunm\imu_data_0314-031355.csv
# Processing file: water_fusion\raw_data\imu_data_0314-031436.csv
# File has been saved to: water_fusion\allcolunm\imu_data_0314-031436.csv
# Processing file: water_fusion\raw_data\imu_data_0314-031708.csv
# File has been saved to: water_fusion\allcolunm\imu_data_0314-031708.csv
# Processing file: water_fusion\raw_data\imu_data_0314-031818.csv
# File has been saved to: water_fusion\allcolunm\imu_data_0314-031818.csv
# Processing file: water_fusion\raw_data\imu_data_0314-031852.csv
# File has been saved to: water_fusion\allcolunm\imu_data_0314-031852.csv
# Processing file: water_fusion\raw_data\imu_data_0314-032002.csv
# File has been saved to: water_fusion\allcolunm\imu_data_0314-032002.csv
# Processing file: water_fusion\raw_data\imu_data_0314-032043.csv
# File has been saved to: water_fusion\allcolunm\imu_data_0314-032043.csv
# Processing file: water_fusion\raw_data\imu_data_0314-032127.csv
# File has been saved to: water_fusion\allcolunm\imu_data_0314-032127.csv
# Processing file: water_fusion\raw_data\imu_data_0314-032213.csv
# File has been saved to: water_fusion\allcolunm\imu_data_0314-032213.csv
# Processing file: water_fusion\raw_data\imu_data_0314-032258.csv
# File has been saved to: water_fusion\allcolunm\imu_data_0314-032258.csv
# Processing file: water_fusion\raw_data\imu_data_0314-032337.csv
# File has been saved to: water_fusion\allcolunm\imu_data_0314-032337.csv
# Processing file: water_fusion\raw_data\imu_data_0314-032428.csv
# File has been saved to: water_fusion\allcolunm\imu_data_0314-032428.csv
# Processing file: water_fusion\raw_data\imu_data_0314-032833.csv
# File has been saved to: water_fusion\allcolunm\imu_data_0314-032833.csv
# Processing file: water_fusion\raw_data\imu_data_0314-033415.csv
# File has been saved to: water_fusion\allcolunm\imu_data_0314-033415.csv
# Processing file: water_fusion\raw_data\imu_data_0314-033519.csv
# File has been saved to: water_fusion\allcolunm\imu_data_0314-033519.csv
# Processing file: water_fusion\raw_data\imu_data_0314-034137.csv
# File has been saved to: water_fusion\allcolunm\imu_data_0314-034137.csv

# %%
import pandas as pd
import numpy as np
import os

def create_dataset(folder_path, input_size=150, label_size=1, step_size=1):
    all_features = []
    all_labels = []
    
    for file in os.listdir(folder_path):
        if file.endswith('.csv'):
            file_path = os.path.join(folder_path, file)
            df = pd.read_csv(file_path)
            features, labels = process_file(df, input_size, label_size, step_size, file)
            all_features.extend(features)
            all_labels.extend(labels)

    return np.array(all_features), np.array(all_labels)

def process_file(df, input_size, label_size, step_size, file_name):
    if df.empty or len(df.columns) < 2:
        return [], []

    features_list = []
    labels_list = []

    for start in range(0, len(df) - input_size - label_size + 1, step_size):
        end = start + input_size
        label_end = end + label_size

        # Calculate the mean and standard deviation within the current window
        window_mean = df.iloc[start:end, :].mean().values
        window_std = df.iloc[start:end, :].std().values
        if window_std[0] == 0 or window_std[1] == 0 or window_std[2] == 0:
            print(f"File {file_name}: Skipping window with zero standard deviation.")
            continue

        features1 = (df.iloc[start:end, 0].values - window_mean[0]) / window_std[0]  
        features2 = (df.iloc[start:end, 1].values - window_mean[1]) / window_std[1]  
        features3 = (df.iloc[start:end, 2].values - window_mean[2]) / window_std[2]  
        labels = df.iloc[end:label_end, -1].values

        features = np.column_stack((features1, features2, features3))

        features_list.append(features)
        labels_list.append(labels)

    return features_list, labels_list

input_folders = [
    # 'grass_fusion',
    # 'grass2mat_fusion',
    'mat_fusion',
    # 'water_fusion'
]

# 遍历所有文件夹
for input_folder in input_folders:
    input_folder0 = os.path.join(input_folder, '150data')
    features, labels = create_dataset(input_folder0)
    features_path = os.path.join(input_folder, 'features3_150_150normalization.npy')
    labels_path = os.path.join(input_folder, 'labels3_150_150normalization.npy')

    np.save(features_path, features)
    np.save(labels_path, labels)
